# %%
import pandas as pd 
import matplotlib.pyplot as plt

main_dir = "bench-output"

# %%
# insert-random plot

df = pd.read_csv("bench-output/insert-random.csv")

parts = df["Name"].str.split("/", expand=True)

df["Size"] = pd.to_numeric(parts[1], errors="coerce")
df["DS"]   = parts[2]

# Keep only rows where parsing worked
df = df.dropna(subset=["Size", "DS", "Mean"])
df["Size"] = df["Size"].astype(int)

# Split into two frames
rbt = df[df["DS"] == "RBT"].sort_values("Size")
bst = df[df["DS"] == "BST"].sort_values("Size")

x1, y1 = rbt["Size"].to_numpy(), rbt["Mean"].to_numpy()
x2, y2 = bst["Size"].to_numpy(), bst["Mean"].to_numpy()

plt.figure(figsize=(10, 6))
#plt.title("Plot comparing the best case scenario for insertion when elements are inserted into BST and RBT random order")
plt.xlabel("Input Size")
plt.ylabel("Average time (s)")
plt.xscale("log", base=2)
#plt.yscale("log", base=2)

plt.plot(x1, y1, marker="o", label="RBT")
plt.plot(x2, y2, marker="o", label="BST")

plt.grid(True, which="both", linestyle=":")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# insert sorted

df = pd.read_csv("bench-output/insert-sorted.csv")

parts = df["Name"].str.split("/", expand=True)

df["Size"] = pd.to_numeric(parts[1], errors="coerce")
df["DS"]   = parts[2]

# Keep only rows where parsing worked
df = df.dropna(subset=["Size", "DS", "Mean"])
df["Size"] = df["Size"].astype(int)

# Split into two frames
rbt = df[df["DS"] == "RBT"].sort_values("Size")
bst = df[df["DS"] == "BST"].sort_values("Size")

x1, y1 = rbt["Size"].to_numpy(), rbt["Mean"].to_numpy()
x2, y2 = bst["Size"].to_numpy(), bst["Mean"].to_numpy()

plt.figure(figsize=(10, 6))
#plt.title("Plot comparing the worst case scenario for insertion when elements are inserted into BST and RBT in random order")
plt.xlabel("Input Size")
plt.ylabel("Average time (s)")
plt.xscale("log", base=2)
#plt.yscale("log", base=2)

plt.plot(x1, y1, marker="o", label="RBT")
plt.plot(x2, y2, marker="o", label="BST")

plt.grid(True, which="both", linestyle=":")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Delete sorted

df = pd.read_csv("bench-output/delete-sorted.csv")

parts = df["Name"].str.split("/", expand=True)

df["Size"] = pd.to_numeric(parts[1], errors="coerce")
df["DS"]   = parts[2]

# Keep only rows where parsing worked
df = df.dropna(subset=["Size", "DS", "Mean"])
df["Size"] = df["Size"].astype(int)

# Split into two frames
rbt = df[df["DS"] == "RBT"].sort_values("Size")
bst = df[df["DS"] == "BST"].sort_values("Size")

x1, y1 = rbt["Size"].to_numpy(), rbt["Mean"].to_numpy()
x2, y2 = bst["Size"].to_numpy(), bst["Mean"].to_numpy()  

plt.figure(figsize=(10, 6))
#plt.title("Plot comparing the worst case scenario for deleting elements when the BST and RBT are built from sorted inputs")
plt.xlabel("Input Size")
plt.ylabel("Average time (s)")
plt.xscale("log", base=2)
#plt.yscale("log", base=2)

plt.plot(x1, y1, marker="o", label="RBT")
plt.plot(x2, y2, marker="o", label="BST")

plt.grid(True, which="both", linestyle=":")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Delete random

df = pd.read_csv("bench-output/delete-random.csv")

parts = df["Name"].str.split("/", expand=True)

df["Size"] = pd.to_numeric(parts[1], errors="coerce")
df["DS"]   = parts[2]

# Keep only rows where parsing worked
df = df.dropna(subset=["Size", "DS", "Mean"])
df["Size"] = df["Size"].astype(int)

# Split into two frames
rbt = df[df["DS"] == "RBT"].sort_values("Size")
bst = df[df["DS"] == "BST"].sort_values("Size")

x1, y1 = rbt["Size"].to_numpy(), rbt["Mean"].to_numpy()
x2, y2 = bst["Size"].to_numpy(), bst["Mean"].to_numpy()  

plt.figure(figsize=(10, 6))
#plt.title("Plot comparing the best case scenario for deleting elements when the BST and RBT are built from random ordered inputs")
plt.xlabel("Input Size")
plt.ylabel("Average time (s)")
plt.xscale("log", base=2)
#plt.yscale("log", base=2)

plt.plot(x1, y1, marker="o", label="RBT")
plt.plot(x2, y2, marker="o", label="BST")

plt.grid(True, which="both", linestyle=":")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# contains random

df = pd.read_csv("bench-output/contains-random.csv")

parts = df["Name"].str.split("/", expand=True)

df["Size"] = pd.to_numeric(parts[1], errors="coerce")
df["DS"]   = parts[2]

# Keep only rows where parsing worked
df = df.dropna(subset=["Size", "DS", "Mean"])
df["Size"] = df["Size"].astype(int)

# Split into two frames
rbt = df[df["DS"] == "RBT"].sort_values("Size")
bst = df[df["DS"] == "BST"].sort_values("Size")

x1, y1 = rbt["Size"].to_numpy(), rbt["Mean"].to_numpy()
x2, y2 = bst["Size"].to_numpy(), bst["Mean"].to_numpy()

plt.figure(figsize=(10, 6))
#plt.title("Plot comparing the best case scenario for searching for elements when the BST and RBT are built from random list")
plt.xlabel("Input Size")
plt.ylabel("Average time (s)")
plt.xscale("log", base=2)
#plt.yscale("log", base=2)

plt.plot(x1, y1, marker="o", label="RBT")
plt.plot(x2, y2, marker="o", label="BST")

plt.grid(True, which="both", linestyle=":")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# contains sorted

df = pd.read_csv("bench-output/contains-sorted.csv")

parts = df["Name"].str.split("/", expand=True)

df["Size"] = pd.to_numeric(parts[1], errors="coerce")
df["DS"]   = parts[2]

# Keep only rows where parsing worked
df = df.dropna(subset=["Size", "DS", "Mean"])
df["Size"] = df["Size"].astype(int)

# Split into two frames
rbt = df[df["DS"] == "RBT"].sort_values("Size")
bst = df[df["DS"] == "BST"].sort_values("Size")

x1, y1 = rbt["Size"].to_numpy(), rbt["Mean"].to_numpy()
x2, y2 = bst["Size"].to_numpy(), bst["Mean"].to_numpy()

plt.figure(figsize=(10, 6))
#plt.title("Plot of comparing the worst case scenario for searching when the BST and RBT are built from sorted inputs")
plt.xlabel("Input Size")
plt.ylabel("Average time (s)")
plt.xscale("log", base=2)
#plt.yscale("log", base=2)

plt.plot(x1, y1, marker="o", label="RBT")
plt.plot(x2, y2, marker="o", label="BST")

plt.grid(True, which="both", linestyle=":")
plt.legend() 
plt.tight_layout()
plt.show()
